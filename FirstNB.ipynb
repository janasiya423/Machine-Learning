# %%
import numpy as np

# %%
import pandas as pd

# %%
dataframe=pd.read_csv(r'C:\Users\toshiba\Desktop\PYTHON\dataset.csv')
dataframe
# Out:
#      Address                 F.S            P.C.S                   M.E  \
# 0      Urban      Greater than 3  Living together      Higher Education
# 1      Urban      Greater than 3            Apart   Secondary Education
# 2      Rural      Greater than 3  Living together  Elementary Education
# 3      Rural      Greater than 3  Living together   Secondary Education
# 4      Urban      Greater than 3  Living together   Secondary Education
# ...      ...                 ...              ...                   ...
# 1198   Rural  Less or equal to 3            Apart  Elementary Education
# 1199   Urban  Less or equal to 3  Living together  Elementary Education
# 1200   Urban  Less or equal to 3  Living together   Secondary Education
# 1201   Rural      Greater than 3            Apart                   NaN
# 1202   Urban      Greater than 3  Living together   Secondary Education
#
#                        F.E  M.J  F.J     HTS trave ltime            DST  \
# ...

# %%
dataframe.head(15)
# Out:
#    Address                 F.S            P.C.S                   M.E  \
# 0    Urban      Greater than 3  Living together      Higher Education
# 1    Urban      Greater than 3            Apart   Secondary Education
# 2    Rural      Greater than 3  Living together  Elementary Education
# 3    Rural      Greater than 3  Living together   Secondary Education
# 4    Urban      Greater than 3  Living together   Secondary Education
# 5    Urban      Greater than 3  Living together   Secondary Education
# 6    Urban      Greater than 3  Living together   Secondary Education
# 7    Rural  Less or equal to 3            Apart   Secondary Education
# 8    Urban      Greater than 3  Living together   Secondary Education
# 9    Urban      Greater than 3            Apart   Secondary Education
# 10   Urban      Greater than 3  Living together   Secondary Education
# 11   Urban  Less or equal to 3  Living together   Secondary Education
# ...

# %%
dataframe.tail(10)
# Out:
#      Address                 F.S            P.C.S                   M.E  \
# 1193   Urban      Greater than 3  Living together   Secondary Education
# 1194   Urban      Greater than 3            Apart  Elementary Education
# 1195   Rural  Less or equal to 3            Apart  Elementary Education
# 1196   Urban      Greater than 3            Apart   Secondary Education
# 1197   Urban  Less or equal to 3  Living together  Elementary Education
# 1198   Rural  Less or equal to 3            Apart  Elementary Education
# 1199   Urban  Less or equal to 3  Living together  Elementary Education
# 1200   Urban  Less or equal to 3  Living together   Secondary Education
# 1201   Rural      Greater than 3            Apart                   NaN
# 1202   Urban      Greater than 3  Living together   Secondary Education
#
#                        F.E  M.J  F.J     HTS trave ltime             DST  \
# 1193      Higher Education   No   No       15 to 30 min,  5 to 10 hours,
# ...

# %%
dataframe.dtypes
# Out:
# Address                                 object
# F.S                                     object
# P.C.S                                   object
# M.E                                     object
# F.E                                     object
# M.J                                     object
# F.J                                     object
# HTS trave ltime                         object
# DST                                     object
# Failures                                object
# E.C                                     object
# Attended nursery school                 object
# Wants to take higher education          object
# Internet access at home                 object
# In a relationship                       object
# Going out with friends                  object
# Current health status                   object
# No of absences from class in a month    object
# Grade at Class 8                        object
# 9th Class first term Grade              object
# ...

# %%
dataframe.describe
# Out:
# <bound method NDFrame.describe of      Address                 F.S            P.C.S                   M.E  \
# 0      Urban      Greater than 3  Living together      Higher Education
# 1      Urban      Greater than 3            Apart   Secondary Education
# 2      Rural      Greater than 3  Living together  Elementary Education
# 3      Rural      Greater than 3  Living together   Secondary Education
# 4      Urban      Greater than 3  Living together   Secondary Education
# ...      ...                 ...              ...                   ...
# 1198   Rural  Less or equal to 3            Apart  Elementary Education
# 1199   Urban  Less or equal to 3  Living together  Elementary Education
# 1200   Urban  Less or equal to 3  Living together   Secondary Education
# 1201   Rural      Greater than 3            Apart                   NaN
# 1202   Urban      Greater than 3  Living together   Secondary Education
#
# ...

# %%
dataframe.describe(include="all")
# Out:
#        Address             F.S            P.C.S                  M.E  \
# count     1203            1203             1203                 1043
# unique       2               2                2                    3
# top      Urban  Greater than 3  Living together  Secondary Education
# freq       667             707              711                  458
#
#                          F.E   M.J   F.J HTS trave ltime            DST  \
# count                   1074  1203  1203            1203           1203
# unique                     3     2     2               4              4
# top     Elementary Education    No   Yes   15 to 30 min,  2 to 5 hours,
# freq                     436   724   773             532            565
#
#        Failures  ... Internet access at home  In a relationship   \
# count      1203  ...                     1203               1203
# unique        2  ...                        2                  2
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Address                               1203 non-null   object
#  1   F.S                                   1203 non-null   object
#  2   P.C.S                                 1203 non-null   object
#  3   M.E                                   1043 non-null   object
#  4   F.E                                   1074 non-null   object
#  5   M.J                                   1203 non-null   object
#  6   F.J                                   1203 non-null   object
#  7   HTS trave ltime                       1203 non-null   object
#  8   DST                                   1203 non-null   object
#  9   Failures                              1203 non-null   object
#  10  E.C                                   1203 non-null   object
# ...

# %%
dataframe.to_csv('saveddataset.csv')
